# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/backtest/blob/main/10_%E5%8F%96%E5%BE%97%E5%8D%B3%E6%99%82%E8%82%A1%E5%83%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #參考資料1：(盤後)[爬蟲實戰] 如何突破證交所的限制，穩穩抓取最新成交資訊?
# https://youtu.be/RddEKFTVpwE
# #參考資料2：(即時) python爬蟲 — 每日即時股價
# https://medium.com/renee0918/python%E7%88%AC%E8%9F%B2-%E6%AF%8F%E6%97%A5%E5%8D%B3%E6%99%82%E8%82%A1%E5%83%B9-1382bc4d38d3

# %%
import requests
import time
for i in range(1,100):
    res = requests.get('http://www.twse.com.tw/exchangeReport/MI_5MINS?response=json&date=&_=1516888449067')
    time.sleep(3)
    print(res)
# Out:
# <Response [200]>
# <Response [200]>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-adb23aa6767f> in <module>()
#       3 for i in range(1,100):
#       4     res = requests.get('http://www.twse.com.tw/exchangeReport/MI_5MINS?response=json&date=&_=1516888449067')
# ----> 5     time.sleep(3)
#       6     print(res)
#
# KeyboardInterrupt:

# %%
res.json()
# Out:
# {'data': [['09:00:00',
#    '371,336',
#    '4,390,400',
#    '403,935',
#    '1,730,484',
#    '0',
#    '0',
#    '0'],
#   ['09:00:05',
#    '374,571',
#    '4,400,971',
#    '407,256',
#    '1,767,915',
#    '26,022',
#    '114,867',
#    '5,858'],
#   ['09:00:10',
#    '378,103',
#    '4,404,940',
#    '409,987',
#    '1,779,985',
#    '39,668',
#    '171,167',
#    '7,706'],
#   ['09:00:15',
#    '382,166',
#    '4,491,604',
#    '414,481',
#    '1,831,284',
#    '58,199',
#    '231,888',
#    '10,927'],
#   ['09:00:20',
#    '386,713',
#    '4,801,244',
#    '418,404',
#    '1,931,374',
#    '70,082',
#    '268,795',
#    '12,356'],
#   ['09:00:25',
#    '390,631',
#    '4,860,478',
#    '421,448',
#    '1,986,005',
#    '73,416',
#    '279,511',
#    '12,801'],
#   ['09:00:30',
#    '394,285',
#    '4,879,405',
#    '424,316',
#    '1,995,505',
#    '76,393',
#    '291,244',
#    '13,300'],
#   ['09:00:35',
#    '399,006',
#    '5,269,927',
#    '428,411',
#    '2,268,717',
# ...

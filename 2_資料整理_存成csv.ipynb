# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/backtest/blob/main/2_%E8%B3%87%E6%96%99%E6%95%B4%E7%90%86_%E5%AD%98%E6%88%90csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Remote Data Access
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
# #colab內已巿裝有pandas_DataReader
# https://ithelp.ithome.com.tw/articles/10205113

# %%
import pandas_datareader as pdr
df_2330 = pdr.DataReader('2330.TW', 'yahoo')
df_2330.plot()

# %%
startTime = '2018-10-01'
endTime = '2018-10-30'
df_2330 = pdr.DataReader('2330.TW', 'yahoo', startTime, endTime)
df_2330.plot()

# %%
df_2330.head()
# Out:
#              High    Low   Open  Close    Volume   Adj Close
# Date
# 2018-10-01  264.0  261.0  262.0  263.0  22254380  243.868881
# 2018-10-02  263.0  257.0  262.0  257.5  38391491  238.768982
# 2018-10-03  260.0  257.0  257.5  260.0  25228536  241.087112
# 2018-10-04  257.5  254.0  257.0  254.0  36408727  235.523560
# 2018-10-05  253.0  248.5  250.0  250.0  40204660  231.814545

# %%
df_2330.describe()
# Out:
#              High         Low        Open       Close        Volume   Adj Close
# count   22.000000   22.000000   22.000000   22.000000  2.200000e+01   22.000000
# mean   240.045455  235.181818  237.545455  237.795455  4.025299e+07  220.497774
# std     12.694120   13.061708   13.117517   12.685443  1.760988e+07   11.762679
# min    222.000000  217.000000  220.500000  219.500000  1.846379e+07  203.533157
# 25%    233.625000  227.250000  229.625000  229.625000  2.888478e+07  212.921673
# 50%    237.000000  230.250000  233.000000  236.750000  3.810478e+07  219.528366
# 75%    246.125000  241.750000  245.000000  243.875000  4.386518e+07  226.135090
# max    264.000000  261.000000  262.000000  263.000000  9.458966e+07  243.868881

# %% [markdown]
# #2.去除多餘欄位drop, axis=1

# %%
df=df_2330.drop(['Volume','Adj Close'],axis=1)

# %%
df.sample(5)
# Out:
#              High    Low   Open  Close
# Date
# 2018-10-31  234.0  228.0  228.0  234.0
# 2018-10-23  234.0  230.0  232.0  230.0
# 2018-10-19  236.5  230.0  231.0  236.0
# 2018-10-24  231.0  227.0  230.0  229.5
# 2018-10-04  257.5  254.0  257.0  254.0

# %%
df.plot()

# %%
df.plot(figsize=(20,10))

# %% [markdown]
# #3.取出所需欄位, 並建立新欄位
# 【Trade 學院】—《Python程式交易~零基礎10小時快速上手 EP04》資料取得與處 20201102
#
# https://youtu.be/T5eEctR591o?t=1073

# %%
df['ma_short']=df.iloc[:,3].rolling(5).mean()

# %%
df.head(10)
# Out:
#              High    Low   Open  Close  ma_short
# Date
# 2018-10-01  264.0  261.0  262.0  263.0       NaN
# 2018-10-02  263.0  257.0  262.0  257.5       NaN
# 2018-10-03  260.0  257.0  257.5  260.0       NaN
# 2018-10-04  257.5  254.0  257.0  254.0       NaN
# 2018-10-05  253.0  248.5  250.0  250.0     256.9
# 2018-10-08  246.5  241.0  245.5  243.5     253.0
# 2018-10-09  245.0  242.0  243.5  244.0     250.3
# 2018-10-11  233.5  227.0  233.5  227.5     243.8
# 2018-10-12  237.0  229.0  231.0  237.0     240.4
# 2018-10-15  234.0  230.5  234.0  230.5     236.5

# %% [markdown]
# #4.存成csv檔
# 可方便下載到本機,並利用sqlite studio將資料轉成sqlite資料庫

# %%
df.to_csv('aaa.csv')

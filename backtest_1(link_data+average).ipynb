# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/trade-backtest/blob/main/backtest_1(link_data%2Baverage).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/tewei0328/data/master/TX11_day.csv')

# %%
df.head()
# Out:
#          date   open   high    low  close
# 0  2019/10/18  11166  11245  11132  11149
# 1  2019/10/17  11131  11166  11098  11158
# 2  2019/10/16  11097  11147  11088  11131
# 3  2019/10/15  11053  11098  11030  11087
# 4  2019/10/14  10862  11068  10758  11056

# %%
df['ma5']=df['close'].rolling(5).mean()
df['ma20']=df['close'].rolling(20).mean()

# %%
df.head(20)
# Out:
#           date   open   high    low  close      ma5     ma20
# 0   2019/10/18  11166  11245  11132  11149      NaN      NaN
# 1   2019/10/17  11131  11166  11098  11158      NaN      NaN
# 2   2019/10/16  11097  11147  11088  11131      NaN      NaN
# 3   2019/10/15  11053  11098  11030  11087      NaN      NaN
# 4   2019/10/14  10862  11068  10758  11056  11116.2      NaN
# 5    2019/10/9  10986  10986  10863  10865  11059.4      NaN
# 6    2019/10/8  10893  10998  10885  10981  11024.0      NaN
# 7    2019/10/7  10847  10916  10838  10894  10976.6      NaN
# 8    2019/10/4  10848  10893  10801  10860  10931.2      NaN
# 9    2019/10/3  10903  10903  10759  10833  10886.6      NaN
# 10   2019/10/2  10940  10943  10884  10906  10894.8      NaN
# 11   2019/10/1  10819  10942  10753  10935  10885.6      NaN
# 12   2019/9/27  10828  10877  10792  10805  10867.8      NaN
# 13   2019/9/26  10818  10875  10776  10825  10860.8      NaN
# ...

# %%
df.loc[4,'ma5']
# Out:
# 11116.2

# %%
for i in range(len(df)):
    if i>1:
        if df.loc[i-1,'ma5']>df.loc[i-1,'ma20'] and df.loc[i,'ma5']<=df.loc[i,'ma20']:
            df.loc[i,'sk']=-1
        if df.loc[i-1,'ma5']<df.loc[i-1,'ma20'] and df.loc[i,'ma5']>=df.loc[i,'ma20']:
            df.loc[i,'sk']=1

# %%
df['close'].plot()
# Out:
# <Axes: >

# %%
df[['close','ma5','ma20']].plot()
# Out:
# <Axes: >

# %%
df[['close','ma5','ma20']].plot(figsize=(20,5))
# Out:
# <Axes: >

# %% [markdown]
# https://blog.csdn.net/brucewong0516/article/details/80524442
#
# 首先看官网的DataFrame.plot( )函数
#
# DataFrame.plot(x=None, y=None, kind='line', ax=None, subplots=False,
#                 sharex=None, sharey=False, layout=None,figsize=None,
#                 use_index=True, title=None, grid=None, legend=True,
#                 style=None, logx=False, logy=False, loglog=False,
#                 xticks=None, yticks=None, xlim=None, ylim=None, rot=None,
#                 xerr=None,secondary_y=False, sort_columns=False, **kwds)
#
# #              figsize : a tuple (width, height) in inches#图片尺寸大小
